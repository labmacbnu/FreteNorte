# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore, auth
from firebase_admin.firestore import FieldFilter
from datetime import datetime
import json 
from dotenv import load_dotenv
from random import randint
import os
import re
from unidecode import unidecode

load_dotenv()

cred = credentials.Certificate(os.getenv("firebase_secret"))
app = firebase_admin.initialize_app(cred)
db = firestore.client()

# %%
ambiente_origem = "A008"

# %%
ambientes_destino_texto = """A109 - SANITÁRIO FEMININO (1º Andar)
A111 - SANITÁRIO MASCULINO (1º Andar)
A209 - SANITÁRIO PDC FEMININO (2º Andar)
A210 - SANITÁRIO PCD FEMININO (2º Andar)
A212 - SANITÁRIO MASCULINO (2º Andar)
A214 - SANITÁRIO MASCULINO (2º Andar)
A308 - SANITÁRIO PCD FEMININO (3º Andar)
A309 - SANITÁRIO PCD FEMININO (3º Andar)
A311 - SANITÁRIO PCD MASCULINO (3º Andar)
A312 - SANITÁRIO MASCULINO (3º Andar)
B006 - SANITÁRIO MASCULINO (Térreo)
B007 - SANITÁRIO FEMININO (Térreo)
B009 - SANITÁRIO MASCULINO [INATIVO] (Térreo)
B101 - SANITÁRIO FEMININO (1º Andar)
B102 - SANITÁRIO MASCULINO (1º Andar)
B108 - SANITÁRIO MASCULINO (1º Andar)
B109 - SANITÁRIO FEMININO (1º Andar)"""

# %%
AMBIENTES_DESTINO = [ambiente.split(" - ")[0] for ambiente in ambientes_destino_texto.split("\n")]

# %%
pesquisa = db.collection("ambientes-norte") 

BANHEIROS_NORTE = []
for ambiente_norte in pesquisa.stream():
    doc = ambiente_norte.to_dict()
    if doc["detalhes"]["tipo_de_ambiente"] == "Banheiro":
        BANHEIROS_NORTE.append(doc)

# %%
len(AMBIENTES_DESTINO)
# Out:
# 17

# %%
BANHEIROS_NORTE
# Out:
# [{'origem': [],
#   'codigo': 'A022',
#   'nome': 'Banheiros 01 (Masculino e Feminino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 23.47,
#    'nomenclatura': 'Banheiro 01',
#    'pavimento': 'Térreo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco A'}},
#  {'origem': [],
#   'codigo': 'A027',
#   'nome': 'Banheiros 02 (Feminino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 23.53,
#    'nomenclatura': 'Banheiro 02',
#    'pavimento': 'Térreo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco A'}},
#  {'origem': [],
#   'codigo': 'A028',
#   'nome': 'Banheiros 03 (Masculino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 23.53,
#    'nomenclatura': 'Banheiro 03',
#    'pavimento': 'Térreo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco A'}},
#  {'origem': [],
#   'codigo': 'A029.1',
#   'nome': 'Banheiros 04 (Feminino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 9.45,
#    'nomenclatura': 'Banheiro 04',
#    'pavimento': 'Térreo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco A'}},
#  {'origem': [],
#   'codigo': 'A029.2',
#   'nome': 'Banheiros 05 (Masculino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 6.49,
#    'nomenclatura': 'Banheiro 05',
#    'pavimento': 'Térreo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco A'}},
#  {'origem': [],
#   'codigo': 'A029.7',
#   'nome': 'Banheiros 06 (RU)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 8.69,
#    'nomenclatura': 'Banheiro 06',
#    'pavimento': 'Térreo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco A'}},
#  {'origem': [],
#   'codigo': 'A029.8',
#   'nome': 'Banheiros 07 (RU)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 7.85,
#    'nomenclatura': 'Banheiro 07',
#    'pavimento': 'Térreo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco A'}},
#  {'origem': [],
#   'codigo': 'A030.2',
#   'nome': 'Vestiário 01 (Masculino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 12.58,
#    'nomenclatura': 'Vestiário 01',
#    'pavimento': 'Térreo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco A'}},
#  {'origem': [],
#   'codigo': 'A030.3',
#   'nome': 'Vestiário 02 (Feminino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 12.58,
#    'nomenclatura': 'Vestiário 02',
#    'pavimento': 'Térreo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco A'}},
#  {'origem': [],
#   'codigo': 'A109',
#   'nome': 'Banheiro 08 (Feminino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 28.56,
#    'nomenclatura': 'Banheiro 08',
#    'pavimento': 'Superior',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco A'}},
#  {'origem': [],
#   'codigo': 'A110',
#   'nome': 'Banheiro 09 (Masculino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 28.66,
#    'nomenclatura': 'Banheiro 09',
#    'pavimento': 'Superior',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco A'}},
#  {'origem': [],
#   'codigo': 'B006',
#   'nome': 'Banheiro 10 (Feminino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 29.95,
#    'nomenclatura': 'Banheiro 10',
#    'pavimento': 'Térreo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco B'}},
#  {'origem': [],
#   'codigo': 'B007',
#   'nome': 'Banheiro 11 (Masculino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 36.57,
#    'nomenclatura': 'Banheiro 11',
#    'pavimento': 'Térreo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco B'}},
#  {'origem': [],
#   'codigo': 'B008',
#   'nome': 'Banheiro 12 (Acessibilidade)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 5.46,
#    'nomenclatura': 'Banheiro 12',
#    'pavimento': 'Térreo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco B'}},
#  {'origem': [],
#   'codigo': 'B107',
#   'nome': 'Banheiro 13 (Feminino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 29.95,
#    'nomenclatura': 'Banheiro 13',
#    'pavimento': 'Andar 1',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco B'}},
#  {'origem': [],
#   'codigo': 'B108',
#   'nome': 'Banheiro 14 (Masculino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 36.57,
#    'nomenclatura': 'Banheiro 14',
#    'pavimento': 'Andar 1',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco B'}},
#  {'origem': [],
#   'codigo': 'B109',
#   'nome': 'Banheiro 15 (Acessibilidade)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 5.46,
#    'nomenclatura': 'Banheiro 15',
#    'pavimento': 'Andar 1',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco B'}},
#  {'origem': [],
#   'codigo': 'B211',
#   'nome': 'Banheiro 16 (Masculino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 27.57,
#    'nomenclatura': 'Banheiro 16',
#    'pavimento': 'Andar 2',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco B'}},
#  {'origem': [],
#   'codigo': 'B212',
#   'nome': 'Banheiro 17 (Feminino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 14.19,
#    'nomenclatura': 'Banheiro 17',
#    'pavimento': 'Andar 2',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco B'}},
#  {'origem': [],
#   'codigo': 'B311',
#   'nome': 'Banheiro 16 (Masculino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 27.57,
#    'nomenclatura': 'Banheiro 16',
#    'pavimento': 'Andar 3',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco B'}},
#  {'origem': [],
#   'codigo': 'B312',
#   'nome': 'Banheiro 17 (Feminino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Esquerda',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 14.19,
#    'nomenclatura': 'Banheiro 17',
#    'pavimento': 'Andar 3',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco B'}},
#  {'origem': [],
#   'codigo': 'BS03.1',
#   'nome': 'Vestiário 04',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Central',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 1.46,
#    'nomenclatura': 'Vestiário 04',
#    'pavimento': 'Subsolo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco B'}},
#  {'origem': [],
#   'codigo': 'BS03.2',
#   'nome': 'Vestiário 03',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Central',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 1.46,
#    'nomenclatura': 'Vestiário 03',
#    'pavimento': 'Subsolo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco B'}},
#  {'origem': [],
#   'codigo': 'BS03.3',
#   'nome': 'Banheiro 18',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Central',
#    'setor_responsavel': 'Administração de Edifícios',
#    'dimensao_m': 2.43,
#    'nomenclatura': 'Banheiro 18',
#    'pavimento': 'Subsolo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco B'}},
#  {'origem': [],
#   'codigo': 'T004',
#   'nome': 'Banheiro 19 (Masculino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Central',
#    'setor_responsavel': 'Direção Administrativa',
#    'dimensao_m': '',
#    'nomenclatura': 'Banheiro 19',
#    'pavimento': 'Térreo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco T'}},
#  {'origem': [],
#   'codigo': 'T005',
#   'nome': 'Banheiro 20 (Feminino)',
#   'campus': 'Norte',
#   'detalhes': {'observacoes': '',
#    'ala': 'Central',
#    'setor_responsavel': 'Direção Administrativa',
#    'dimensao_m': '',
#    'nomenclatura': 'Banheiro 20',
#    'pavimento': 'Térreo',
#    'descricao': '',
#    'sigla': '',
#    'tipo_de_ambiente': 'Banheiro',
#    'construcao': 'Bloco T'}}]

# %%
def destino(ambiente_origem: str):
    if ambiente_origem.startswith("A"):
        return db.document("ambientes-norte/A022")
    elif ambiente_origem.startswith("B"):
        return db.document("ambientes-norte/B006")
    else:
        return None

# %% [markdown]
# ## Itens de origem

# %%
itens_banheiro = []
origem_ref = db.collection('ambientes').document(ambiente_origem)
items_banheiro = db.collection('items').where(filter=FieldFilter('ambiente', '==', origem_ref))
for item in items_banheiro.stream():
    itens_banheiro.append(item.to_dict())

# %%
ordem_itens = [
 '1 Espelho de 64 x 44 x 2cm',
 '1 Dispenser de Sabonete Liquido de 8 x 8 x 16cm',
 '1 Dispenser para Álcool de 25 x 11 x 11cm',
 '1 Lixeiro pequeno de 28 x 28 x 33cm',
 '1 Lixeiro de 41 x 31 x 78cm',
 '1 Porta Toalha de 30 x 25 x 12cm',
 '1 Porta Papel Higiênico de 26 x 28 x 14cm'
 ]

AGRUPAMENTO_VOLUMES = [[0], [1, 2, 3], [4], [5, 6]]

MEDIDAS_VOLUMES = [(64, 44, 2), (40, 40, 50), (78, 41, 31), (40, 40, 50)] 

EMBALAGENS_VOLUMES = [None, 'Caixa_M', None, 'Caixa_M']

PROPRIEDADES_VOLUMES = [["Frágil"], [], [], []]

CATEGORIAS_VOLUMES = ["Vidraria", "Outros", "Outros", "Outros"]

def generate_medida_dict(medidas: tuple):
    return {
        "a": medidas[0],
        "c": medidas[1],
        "l": medidas[2]
    }

ITENS_BANHEIRO_ORDENADOS = []

for ordem in ordem_itens:
    for item in itens_banheiro:
        if item['short_descricao'] == ordem:
            ITENS_BANHEIRO_ORDENADOS.append(item)

# %%
def generate_itens_para_banheiro(cod_banheiro: str):
    itens_para_banheiro = []
    for (n,item) in enumerate(ITENS_BANHEIRO_ORDENADOS):
        new_item  = item.copy()
        new_item['ambiente'] = db.collection('ambientes').document(cod_banheiro)
        new_item['key'] = f"{cod_banheiro}WC{n:02d}"
        new_item['origem'] = cod_banheiro
        itens_para_banheiro.append(new_item)
    return itens_para_banheiro

# %% [markdown]
# # Volume exemplo

# %%
VOLUME_EXEMPLO = db.document("volumes/B1230028").get().to_dict()

# %%
from datetime import datetime

# %%
def create_new_volume(
        codigo: str,
        origem_str: str,
        destino,
        categoria: str,
        items: list,
        medidas: dict,
        embalagem: str | None = None,
        propriedades: list = [],
        ):
    new_volume = VOLUME_EXEMPLO.copy() 
    new_volume['codigo'] = codigo
    new_volume['origem'] = db.document(f"ambientes/{origem_str}")
    new_volume['destino'] = destino
    new_volume['categoria'] = categoria
    new_volume['items'] = items
    new_volume['medidas'] = medidas
    new_volume['embalagem']['caixa'] = embalagem
    new_volume['propriedades'] = propriedades
    new_volume['data_criacao'] = datetime.now()
    new_volume['responsavel'] = db.document(f"usuarios/fabio.metzner@ufsc.br")
    
    return new_volume

# %%
def generate_volumes_banheiro(lista_itens: list):
    origem = lista_itens[0]['origem']
    volumes = []
    for (n, grupo) in enumerate(AGRUPAMENTO_VOLUMES):
        volume = create_new_volume(
            codigo = f"{origem}{n:04d}",
            origem_str = origem,
            destino = destino(origem),
            categoria = CATEGORIAS_VOLUMES[n],
            items = [db.document(f"items/{lista_itens[i]['key']}") for i in grupo],
            medidas = generate_medida_dict(MEDIDAS_VOLUMES[n]),
            embalagem = EMBALAGENS_VOLUMES[n],
            propriedades = PROPRIEDADES_VOLUMES[n]
        )
        volumes.append(volume)
    return volumes

# %% [markdown]
# # Criando os baguio

# %%
primeiros_itens = generate_itens_para_banheiro(ambiente_origem)
primeiros_volumes = generate_volumes_banheiro(primeiros_itens)

ITENS_BANHEIROS_CRIADOS =  primeiros_itens 
VOLUMES_BANHEIRO_CRIADOS = primeiros_volumes 



for banheiro in AMBIENTES_DESTINO:
    itens_banheiro = generate_itens_para_banheiro(banheiro)
    volumes_banheiro = generate_volumes_banheiro(itens_banheiro) 
    ITENS_BANHEIROS_CRIADOS.extend(itens_banheiro)
    VOLUMES_BANHEIRO_CRIADOS.extend(volumes_banheiro)

# %%
VOLUMES_BANHEIRO_CRIADOS
# Out:
# [{'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fdea0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562005),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fe350>,
#   'codigo': 'A00800',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102ff3a0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fea40>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102feb60>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fd5a0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562069),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fe560>,
#   'codigo': 'A00801',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fd720>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac102ffe80>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562095),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fdcc0>,
#   'codigo': 'A00802',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102ffd90>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fd6f0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fe230>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562123),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fe440>,
#   'codigo': 'A00803',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fe470>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fecb0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562348),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102feb30>,
#   'codigo': 'A10900',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fcb20>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac102febf0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fceb0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fce50>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562380),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fea70>,
#   'codigo': 'A10901',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fcee0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fd030>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562404),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fce20>,
#   'codigo': 'A10902',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fd060>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fd0c0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fd390>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562429),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102fcfd0>,
#   'codigo': 'A10903',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac102ff2b0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350130>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562513),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103500a0>,
#   'codigo': 'A11100',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350160>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350280>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103502b0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350310>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562542),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350100>,
#   'codigo': 'A11101',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350370>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350490>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562562),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350250>,
#   'codigo': 'A11102',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103504c0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103505e0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350610>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562587),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350460>,
#   'codigo': 'A11103',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350670>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350a30>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562667),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103509a0>,
#   'codigo': 'A20900',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350a60>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350b80>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350bb0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350c10>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562737),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350a00>,
#   'codigo': 'A20901',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350c70>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350d90>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562798),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350b50>,
#   'codigo': 'A20902',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350dc0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350ee0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350f10>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562832),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350d60>,
#   'codigo': 'A20903',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10350f70>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351330>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 562914),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103512a0>,
#   'codigo': 'A21000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351360>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351480>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103514b0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351510>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563064),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351300>,
#   'codigo': 'A21001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351570>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351690>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563088),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351450>,
#   'codigo': 'A21002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103516c0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103517e0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351810>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563114),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351660>,
#   'codigo': 'A21003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351870>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351c30>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563195),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351ba0>,
#   'codigo': 'A21200',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351c60>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351d80>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351db0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351e10>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563224),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351c00>,
#   'codigo': 'A21201',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351e70>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351f90>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563245),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351d50>,
#   'codigo': 'A21202',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351fc0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103520e0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352110>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563269),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10351f60>,
#   'codigo': 'A21203',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352170>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352530>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563348),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103524a0>,
#   'codigo': 'A21400',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352560>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352680>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103526b0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352710>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563376),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352500>,
#   'codigo': 'A21401',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352770>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352890>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563397),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352650>,
#   'codigo': 'A21402',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103528c0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103529e0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352a10>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563423),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352860>,
#   'codigo': 'A21403',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352a70>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352e30>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563503),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352da0>,
#   'codigo': 'A30800',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352e60>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352f80>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352fb0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353010>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563531),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352e00>,
#   'codigo': 'A30801',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353070>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353190>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563551),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10352f50>,
#   'codigo': 'A30802',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103531c0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103532e0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353310>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563575),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353160>,
#   'codigo': 'A30803',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353370>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353730>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563652),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103536a0>,
#   'codigo': 'A30900',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353760>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353880>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103538b0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353910>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563680),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353700>,
#   'codigo': 'A30901',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353970>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353a90>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563700),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353850>,
#   'codigo': 'A30902',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353ac0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353be0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353c10>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563725),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353a60>,
#   'codigo': 'A30903',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353c70>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c070>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563802),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10353fa0>,
#   'codigo': 'A31100',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c0a0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c1c0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c1f0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c250>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563830),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c040>,
#   'codigo': 'A31101',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c2b0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c3d0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563851),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c190>,
#   'codigo': 'A31102',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c400>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c520>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c550>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563875),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c3a0>,
#   'codigo': 'A31103',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c5b0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c970>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563953),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c8e0>,
#   'codigo': 'A31200',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c9a0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035cac0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035caf0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035cb50>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 563981),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035c940>,
#   'codigo': 'A31201',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035cbb0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035ccd0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564002),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035ca90>,
#   'codigo': 'A31202',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035cd00>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035ce20>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035ce50>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564026),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035cca0>,
#   'codigo': 'A31203',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035ceb0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d270>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564106),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d1e0>,
#   'codigo': 'B00600',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d2a0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d3c0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d3f0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d450>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564135),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d240>,
#   'codigo': 'B00601',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d4b0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d5d0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564156),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d390>,
#   'codigo': 'B00602',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d600>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d720>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d750>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564180),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d5a0>,
#   'codigo': 'B00603',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035d7b0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035db70>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564256),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035dae0>,
#   'codigo': 'B00700',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035dba0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035dcc0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035dcf0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035dd50>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564285),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035db40>,
#   'codigo': 'B00701',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035ddb0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035ded0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564306),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035dc90>,
#   'codigo': 'B00702',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035df00>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e020>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e050>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564330),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035dea0>,
#   'codigo': 'B00703',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e0b0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e470>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564407),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e3e0>,
#   'codigo': 'B00900',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e4a0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e5c0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e5f0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e650>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564435),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e440>,
#   'codigo': 'B00901',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e6b0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e7d0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564456),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e590>,
#   'codigo': 'B00902',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e800>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e920>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e950>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564480),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e7a0>,
#   'codigo': 'B00903',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035e9b0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035ed70>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564558),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035ece0>,
#   'codigo': 'B10100',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035eda0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035eec0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035eef0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035ef50>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564587),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035ed40>,
#   'codigo': 'B10101',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035efb0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f0d0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564607),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035ee90>,
#   'codigo': 'B10102',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f100>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f220>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f250>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 564632),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f0a0>,
#   'codigo': 'B10103',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f2b0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f670>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 565241),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac104e9a50>,
#   'codigo': 'B10200',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac201ad210>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f760>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f790>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f7f0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 565382),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f640>,
#   'codigo': 'B10201',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f850>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f970>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 565453),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f730>,
#   'codigo': 'B10202',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f9a0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035fac0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035faf0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 565563),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035f940>,
#   'codigo': 'B10203',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035fb50>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035ff10>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 566256),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035fe80>,
#   'codigo': 'B10800',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035ff40>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103640a0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103640d0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364130>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 566326),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1035fee0>,
#   'codigo': 'B10801',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364190>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103642b0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 566376),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364070>,
#   'codigo': 'B10802',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103642e0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364400>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364430>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 566433),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364280>,
#   'codigo': 'B10803',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364490>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364850>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 566619),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103647c0>,
#   'codigo': 'B10900',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364880>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103649a0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103649d0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364a30>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 566686),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364820>,
#   'codigo': 'B10901',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364a90>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364bb0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 566734),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364970>,
#   'codigo': 'B10902',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364be0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364d00>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364d30>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 45, 28, 566790),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34368a30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364b80>,
#   'codigo': 'B10903',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364d90>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False}]

# %% [markdown]
# # Escrevendo

# %%
def batch_write(collection: str, dictarray: list[dict], key_id: str | None = None):
    batch = db.batch()
    collection_ref = db.collection(collection)
    k = 1
    for i in range(0, len(dictarray), 500):
        chunk = dictarray[i:i+500]
        for document in chunk:
            if key_id:
                doc_ref = collection_ref.document(str(document[key_id]))
                batch.set(doc_ref, document)
        print(f"{collection}: chunk {k} ({len(chunk)} documents)")
        k += 1
        batch.commit()

# %%
batch_write("items", ITENS_BANHEIROS_CRIADOS, "key")
# Out:
# items: chunk 1 (126 documents)

# %%
batch_write("volumes", VOLUMES_BANHEIRO_CRIADOS, "codigo")
# Out:
# volumes: chunk 1 (72 documents)

# %%
VOLUMES_BANHEIRO_CRIADOS
# Out:
# [{'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037ffd0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 917944),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037c310>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037dd50>,
#   'codigo': 'A0080000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037e590>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037d630>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037c610>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f9d0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 917991),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f5b0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037d090>,
#   'codigo': 'A0080001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037c820>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f340>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918021),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037e770>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037c2b0>,
#   'codigo': 'A0080002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037e4a0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037c760>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037cca0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918080),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f220>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037fb20>,
#   'codigo': 'A0080003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037c940>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037e4d0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918327),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f940>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037e980>,
#   'codigo': 'A1090000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f580>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037e0b0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037d570>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037e710>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918368),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f910>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037d390>,
#   'codigo': 'A1090001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f520>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037df00>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918398),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037e800>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037dd20>,
#   'codigo': 'A1090002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037cfa0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037d510>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037e530>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918431),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037d9c0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037c490>,
#   'codigo': 'A1090003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037e860>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037ead0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918527),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037c4f0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f0d0>,
#   'codigo': 'A1110000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f760>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037ca60>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037c2e0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037cd60>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918565),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037eda0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f130>,
#   'codigo': 'A1110001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037e440>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037dea0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918593),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037dc60>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037c520>,
#   'codigo': 'A1110002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037ec20>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f820>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037d9f0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918625),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037d0c0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037da20>,
#   'codigo': 'A1110003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037df60>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f7c0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918719),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037e5f0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037dae0>,
#   'codigo': 'A2090000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f8e0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037e470>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f790>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037c280>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918759),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10365360>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037f5e0>,
#   'codigo': 'A2090001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103669e0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103671f0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918791),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367820>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac1037ce20>,
#   'codigo': 'A2090002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103674f0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367220>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367460>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918825),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367be0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367250>,
#   'codigo': 'A2090003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367d90>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10366350>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918921),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10366920>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103675b0>,
#   'codigo': 'A2100000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10365d50>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10365d80>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10365210>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10366cb0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918958),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10365960>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367f40>,
#   'codigo': 'A2100001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103673a0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367700>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 918987),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367b20>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367c10>,
#   'codigo': 'A2100002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10366020>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10365c30>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367c40>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919019),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10365ae0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103670a0>,
#   'codigo': 'A2100003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364f10>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367d30>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919112),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367730>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367490>,
#   'codigo': 'A2120000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103678e0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367e20>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103658a0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367100>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919149),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367e50>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367c70>,
#   'codigo': 'A2120001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10365510>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103656c0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919177),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10365f00>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367640>,
#   'codigo': 'A2120002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103670d0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103673d0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10366440>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919210),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10365390>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10365c60>,
#   'codigo': 'A2120003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10365cf0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10365bd0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919302),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10366b60>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367ca0>,
#   'codigo': 'A2140000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10365ed0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac10364fa0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103657b0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4040>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919341),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4190>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10367670>,
#   'codigo': 'A2140001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a40a0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4220>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919370),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4340>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac10366da0>,
#   'codigo': 'A2140002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4250>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a43d0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4400>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919404),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4550>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a41c0>,
#   'codigo': 'A2140003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4460>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4880>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919501),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a49a0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a47f0>,
#   'codigo': 'A3080000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a48b0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4a30>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4a60>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4ac0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919538),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4c10>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4850>,
#   'codigo': 'A3080001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4b20>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4ca0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919568),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4dc0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a49d0>,
#   'codigo': 'A3080002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4cd0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4e50>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4e80>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919603),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4fd0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4c40>,
#   'codigo': 'A3080003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a4ee0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5300>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919701),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5420>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5270>,
#   'codigo': 'A3090000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5330>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a54b0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a54e0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5540>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919740),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5690>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a52d0>,
#   'codigo': 'A3090001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a55a0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5720>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919932),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5840>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5450>,
#   'codigo': 'A3090002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5750>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a58d0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5900>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 919969),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5a50>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a56c0>,
#   'codigo': 'A3090003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5960>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5d80>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 920066),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5ea0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5cf0>,
#   'codigo': 'A3110000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5db0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5f30>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5f60>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5fc0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 920103),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6110>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5d50>,
#   'codigo': 'A3110001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6020>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a61a0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 920131),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a62c0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a5ed0>,
#   'codigo': 'A3110002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a61d0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6350>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6380>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 920163),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a64d0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6140>,
#   'codigo': 'A3110003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a63e0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6800>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 920257),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6920>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6770>,
#   'codigo': 'A3120000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6830>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a69b0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a69e0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6a40>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 920294),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6b90>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a67d0>,
#   'codigo': 'A3120001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6aa0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6c20>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 920322),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6d40>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6950>,
#   'codigo': 'A3120002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6c50>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6dd0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6e00>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 920354),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6f50>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6bc0>,
#   'codigo': 'A3120003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a6e60>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7280>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 920851),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7340>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a71f0>,
#   'codigo': 'B0060000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac104e9840>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a73d0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7400>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7460>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 920945),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a75b0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7250>,
#   'codigo': 'B0060001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a74c0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7640>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 921010),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7760>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7370>,
#   'codigo': 'B0060002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7670>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a77f0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7820>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 921086),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7970>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a75e0>,
#   'codigo': 'B0060003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7880>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7ca0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 921303),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7dc0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7c10>,
#   'codigo': 'B0070000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7cd0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7e50>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7e80>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7ee0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 921392),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0070>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7c70>,
#   'codigo': 'B0070001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7f40>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0100>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 921459),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0220>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103a7df0>,
#   'codigo': 'B0070002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0130>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b02b0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b02e0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 921535),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0430>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b00a0>,
#   'codigo': 'B0070003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0340>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0760>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 921751),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0880>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b06d0>,
#   'codigo': 'B0090000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0790>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0910>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0940>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b09a0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 921838),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0af0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0730>,
#   'codigo': 'B0090001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0a00>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0b80>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 921903),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0ca0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b08b0>,
#   'codigo': 'B0090002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0bb0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0d30>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0d60>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 921979),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0eb0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0b20>,
#   'codigo': 'B0090003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b0dc0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b11e0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 922117),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1300>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1150>,
#   'codigo': 'B1010000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1210>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1390>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b13c0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1420>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 922199),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1570>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b11b0>,
#   'codigo': 'B1010001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1480>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1600>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 922256),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1720>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1330>,
#   'codigo': 'B1010002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1630>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b17b0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b17e0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 922322),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1930>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b15a0>,
#   'codigo': 'B1010003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1840>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1c60>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 922506),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1d80>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1bd0>,
#   'codigo': 'B1020000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1c90>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1e10>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1e40>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1ea0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 922579),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1ff0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1c30>,
#   'codigo': 'B1020001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1f00>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2080>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 922633),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b21a0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b1db0>,
#   'codigo': 'B1020002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b20b0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2230>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2260>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 922697),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b23b0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2020>,
#   'codigo': 'B1020003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b22c0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b26e0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 922879),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2800>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2650>,
#   'codigo': 'B1080000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2710>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2890>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b28c0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2920>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 922952),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2a70>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b26b0>,
#   'codigo': 'B1080001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2980>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2b00>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 923006),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2c20>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2830>,
#   'codigo': 'B1080002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2b30>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2cb0>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2ce0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 923069),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2e30>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2aa0>,
#   'codigo': 'B1080003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b2d40>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 64, 'c': 44, 'l': 2},
#   'categoria': 'Vidraria',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b3160>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 923252),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b3280>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b30d0>,
#   'codigo': 'B1090000',
#   'propriedades': ['Frágil'],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b3190>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b3310>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b3340>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b33a0>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 923325),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b34f0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b3130>,
#   'codigo': 'B1090001',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b3400>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 78, 'c': 41, 'l': 31},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b3580>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 923380),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b36a0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b32b0>,
#   'codigo': 'B1090002',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b35b0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False},
#  {'medidas': {'a': 40, 'c': 40, 'l': 50},
#   'categoria': 'Outros',
#   'peso': None,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b3730>,
#    <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b3760>],
#   'observacao': '',
#   'servicos': [],
#   'status': ['Criado'],
#   'data_criacao': datetime.datetime(2023, 12, 6, 16, 48, 1, 923443),
#   'embalagem': {'caixa': 'Caixa_M', 'platico_bolha': None, 'enchimento': None},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b38b0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b3520>,
#   'codigo': 'B1090003',
#   'propriedades': [],
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac103b37c0>,
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fac34213fa0>,
#   'deleted': False}]

# %% [markdown]
# Consertando cagadas
#
# ```python
# origens_refs = [db.document(f"ambientes/{x}") for x in [ambiente_origem ] + ambientes_destino]
#
# pesquisa = db.collection("volumes").where(filter=FieldFilter("origem", 'in', origens_refs))
# for volume in pesquisa.stream():
#     volume.reference.delete()
#
# ```
