# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import firestore, auth
from firebase_admin.firestore import FieldFilter
from google.cloud.firestore_v1.document import DocumentReference
from datetime import datetime
import json 
from dotenv import load_dotenv
from random import randint
import os
import re
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'    
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

load_dotenv()

cred = credentials.Certificate(os.getenv("firebase_secret"))
app = firebase_admin.initialize_app(cred)


db = firestore.client()


def load_json_file(filename):
    with open(filename) as fp:
        content = json.load(fp)
    return content

# %%
DB = {
    "volumes": {},
    "items": {},
    "usuarios": {},
    "ambientes": {},
    "ambientes-norte": {}
}

# %%
[ x for x in dir(DocumentReference) if not x.startswith("__") ]
# Out:
# ['_document_path',
#  '_document_path_internal',
#  '_prep_batch_get',
#  '_prep_collections',
#  '_prep_create',
#  '_prep_delete',
#  '_prep_set',
#  '_prep_update',
#  'collection',
#  'collections',
#  'create',
#  'delete',
#  'get',
#  'id',
#  'on_snapshot',
#  'parent',
#  'path',
#  'set',
#  'update']

# %%
"e" not in {"a": 1, "e": -3}
# Out:
# False

# %%
def split_string_ref(str_fullref: str):
    collection, key = str_fullref.split("/")
    return collection, key

def process_reference(reference: DocumentReference):  
    col, id = split_string_ref(reference.path)
    print(f"{bcolors.OKCYAN}Processing {col}/{id}{bcolors.ENDC}")
    if id not in  DB[col] :
        print("API call to get data")
        DB[col][id] = process_dict(reference.get().to_dict())
    return reference.path
    
def process_array(array: list):
    return [process_reference(item) if type(item) == DocumentReference else item for item in array]

def process_dict(input_dict):  
    output_dict = {}
    for key, value in input_dict.items():
        if type(value) == DocumentReference:
            output_dict[key] = process_reference(value)
        elif isinstance(value, dict):
            output_dict[key] = process_dict(value)
        elif isinstance(value, list):
            output_dict[key] = process_array(value)
        elif isinstance(value, datetime):
            output_dict[key] = value.isoformat()
        else:
            output_dict[key] = value
    return output_dict

# %%
CODIGOS_LEMA = ["V353341E" , "V353341I", "B1230028", "V363741", "V347859", "Mp4qqn9Lmzowei87GmSn"]

for chave in  CODIGOS_LEMA:
    doc_ref = db.document(f"volumes/{chave}")
    doc = doc_ref.get()
    if doc.exists:
        print(f"{bcolors.OKGREEN}Documento {chave} encontrado{bcolors.ENDC}")
        DB["volumes"][chave] = {}
        documento = process_dict(doc.to_dict())
        DB["volumes"][chave] = documento
    else:
        print(f"{bcolors.FAIL}Documento {chave} não encontrado{bcolors.ENDC}")
# Out:
# Documento V353341E encontrado
# Processing items/353341-E
# API call to get data
# Processing ambientes/B123
# API call to get data
# Processing usuarios/l.f.bossa@ufsc.br
# API call to get data
# Processing volumes/V353341E
# Processing usuarios/l.f.bossa@ufsc.br
# Processing ambientes/B123
# Processing ambientes-norte/A102
# API call to get data
# Processing ambientes/B123
# Documento V353341I encontrado
# Processing items/353341-I
# API call to get data
# Processing ambientes/B123
# Processing volumes/V353341I
# Processing usuarios/l.f.bossa@ufsc.br
# Processing ambientes/B123
# Processing ambientes-norte/A102
# Processing ambientes/B123
# Documento B1230028 encontrado
# Processing items/363637
# API call to get data
# Processing ambientes/B123
# Processing volumes/B1230028
# Processing usuarios/l.f.bossa@ufsc.br
# Processing ambientes/B123
# Processing ambientes-norte/A102
# Processing ambientes/B123
# Documento V363741 encontrado
# Processing items/363741
# API call to get data
# Processing ambientes/B123
# Processing volumes/V363741
# Processing usuarios/l.f.bossa@ufsc.br
# Processing ambientes/B123
# Processing ambientes-norte/A102
# Processing ambientes/B123
# Documento V347859 encontrado
# Processing items/347859
# API call to get data
# Processing ambientes/B123
# Processing volumes/V347859
# Processing usuarios/l.f.bossa@ufsc.br
# Processing ambientes/B123
# Processing ambientes-norte/A102
# Processing ambientes/B123
# Documento Mp4qqn9Lmzowei87GmSn encontrado
# Processing items/363873
# API call to get data
# Processing ambientes/B123
# Processing volumes/Mp4qqn9Lmzowei87GmSn
# Processing usuarios/l.f.bossa@ufsc.br
# Processing ambientes/B123
# Processing ambientes-norte/A102
# Processing ambientes/B123

# %%
json.dump(DB, open("volumes-lema.json", "w"), indent=4, ensure_ascii=False)

# %% [markdown]
# # Carrega os dados que já estão salvos

# %%
items = load_json_file("json1123/itens.json")
volumes = load_json_file("json1123/volumes.json")

# %%
def load_data_from_fullref(fullref: str):
    collection, key = split_string_ref(fullref)
    if collection == "volumes":  
        return volumes[key]
    elif collection == "items":
        return items[key]

# %%
def batch_write(collection: str, dictarray: list[dict], key_id: str | None = None):
    batch = db.batch()
    collection_ref = db.collection(collection)
    k = 1
    for i in range(0, len(dictarray), 500):
        chunk = dictarray[i:i+500]
        for document in chunk:
            if key_id:
                doc_ref = collection_ref.document(str(document[key_id]))
                batch.set(doc_ref, document)
        print(f"{collection}: chunk {k} ({len(chunk)} documents)")
        k += 1
        batch.commit()

# %%
def batch_soft_delete(fullrefs_list: list): 
    batch = db.batch() 
    k = 1
    for i in range(0, len(fullrefs_list), 500):
        chunk = fullrefs_list[i:i+500]
        for full_ref in chunk: 
            doc_ref = db.document(full_ref)
            batch.update(doc_ref, {'deleted': True})
        print(f"chunk {k} ({len(chunk)} documents)")
        k += 1
        batch.commit()

# %%
import re
import pandas as pd

# %%
ares_condicionados = [ x for x in items.values() if re.match(r".*CONDICION.*", x["short_descricao"])]

# %%
def extract_btus(descricao: str):
    match = re.search(r".*?(\d*\.{0,1}\d+)\s*BTU.*", descricao)
    if match:
        return match.group(1).replace(".", "")
    else:
        return None

# %%
def extract_marca(descricao: str):
    match = re.search(r".*?MARCA:*\s*(\w+).*", descricao)
    if match:
        return match.group(1)
    else:
        return None

# %%
def extract_groups(regex: str, descricao: str):
    match = re.search(regex, descricao)
    if match:
        return match.groups()
    else:
        return None

# %%
def extract_modelo(descricao: str):
    modelo = extract_groups(r"MODELO(.*?),", descricao)
    if modelo:
        return modelo[0]
    else:
        return None

# %%
btus = list(map(lambda x: extract_btus(x["detalhes"]["descricao"]), ares_condicionados))
codigo = [x["key"] for x in ares_condicionados]
short_descricao = [x["short_descricao"] for x in ares_condicionados]
descricao = [x["detalhes"]["descricao"] for x in ares_condicionados]
marca = list(map(lambda x: extract_marca(x["detalhes"]["descricao"]), ares_condicionados))
origem = [x["origem"] for x in ares_condicionados]
modelo = list(map(lambda x: extract_modelo(x["detalhes"]["descricao"]), ares_condicionados))

ares_df = pd.DataFrame({"codigo": codigo, 
                        "short_descricao": short_descricao, 
                        "origem": origem,
                        "descricao": descricao, 
                        "btus": btus, 
                        "marca": marca,
                        "modelo": modelo})

ares_df.btus = ares_df.btus.astype(int)

# %%
ares_df
# Out:
#                    codigo                                    short_descricao  \
# 0                  227811                       CONDICIONADOR DE AR 9000BTUS
# 1                  227821                       CONDICIONADOR DE AR 9000BTUS
# 2                  227828                       CONDICIONADOR DE AR 9000BTUS
# 3                  227831                       CONDICIONADOR DE AR 9000BTUS
# 4                  227839                       CONDICIONADOR DE AR 9000BTUS
# ..                    ...                                                ...
# 154                359953                                CONDICIONADOR DE AR
# 155                363979                 CONDICIONADOR DE AR SPLIT INVERTER
# 156                363980                 CONDICIONADOR DE AR SPLIT INVERTER
# 157                420030                        APARELHO DE AR CONDICIONADO
# 158  KexU3GwlmGt53XCUxqYK  UNIDADE CONDENSADORA DE AR SPLIT INVERTER - CO...
#
#      origem                                          descricao   btus  \
# 0      B110  CONDICIONADOR DE AR 9000BTUS - CONDICIONADOR D...   9000
# 1      A003  CONDICIONADOR DE AR 9000BTUS - CONDICIONADOR D...   9000
# 2      A108  CONDICIONADOR DE AR 9000BTUS - CONDICIONADOR D...   9000
# 3    B003.1  CONDICIONADOR DE AR 9000BTUS - CONDICIONADOR D...   9000
# 4      B019  CONDICIONADOR DE AR 9000BTUS - CONDICIONADOR D...   9000
# ..      ...                                                ...    ...
# 154    B118  CONDICIONADOR DE AR - CONDICIONADOR DE AR SPLI...  24000
# 155    B001  CONDICIONADOR DE AR SPLIT INVERTER - HI-WALL C...   9000
# 156    B119  CONDICIONADOR DE AR SPLIT INVERTER - HI-WALL C...   9000
# 157    B008  APARELHO DE AR CONDICIONADO - AR CONDICIONADO ...  12000
# 158    B117  UNIDADE CONDENSADORA DE AR SPLIT INVERTER - CO...  12000
#
#           marca                                             modelo
# 0          None                                               None
# 1          None                                               None
# 2          None                                               None
# 3          None                                               None
# 4          None                                               None
# ..          ...                                                ...
# 154        GREE                                    GWC24ME-D1NNA8E
# 155       ELGIN  : ELGIN HVFI09B2IA NACIONAL. INVERTER; QUENTE ...
# 156       ELGIN  : ELGIN HVFI09B2IA NACIONAL. INVERTER; QUENTE ...
# 157       ELGIN                                               None
# 158  ELECTROLUX                                               None
#
# [159 rows x 7 columns]

# %% [markdown]
# # Tamanho dos ares

# %%
ARES_SIZES = pd.read_excel("xlsx/arescondicionares.xlsx")

# %%
ARES_SIZES.groupby(["BTUS", "Unidade"]).agg({"A": 'mean', "L": 'mean', "C": 'mean', "Peso": 'mean'})
# Out:
#                     A           L          C        Peso
# BTUS  Unidade
# 9000  Externa   52.40   71.400000  26.600000   24.000000
#       Interna   27.40   75.200000  19.200000    8.000000
# 12000 Externa   55.00   66.333333  33.333333   24.666667
#       Interna   29.00   83.666667  19.333333    9.000000
# 18000 Externa   53.25   77.000000  43.750000   31.250000
#       Interna   32.00   98.750000  26.750000   11.250000
# 22000 Externa   70.00   96.000000  40.000000   50.000000
#       Interna   34.00  108.000000  23.000000   16.000000
# 24000 Externa   58.00   96.500000  53.500000   47.000000
#       Interna   32.00  106.500000  32.500000   11.500000
# 60000 Externa  116.00   87.000000  33.000000  101.000000
#       Interna   68.00  129.000000  25.000000   49.000000

# %%
[x["meta"]["partes"] for x in ares_condicionados if x["meta"]["inteiro"] == False]
# Out:
# [['items/322601-2', 'items/322601-3'], ['items/322607-3', 'items/322607-4']]

# %%
def print_link_to_data(fullref: str):
    url = "https://console.firebase.google.com/u/0/project/frete-norte-ufsc-blumenau/firestore/data/"
    print(f"{bcolors.OKBLUE}{url}{fullref}{bcolors.ENDC}")

# %%
def match_modelo(modelo_raw: str | None):
    if modelo_raw == None:
        return None
    unique_modelos = ARES_SIZES["Modelo"].unique()
    for modelo in unique_modelos:
        if modelo in modelo_raw:
            return modelo

# %%
ares_df["real_modelo"] = ares_df.modelo.apply(match_modelo)

# %%
from copy import deepcopy

# %% [markdown]
# # Ambientes norte?

# %%
ambientes_norte = load_json_file("json0929/ambientes-norte.json")

# %%
def find_destino(origem: str):
    for ambiente in ambientes_norte:
        if origem in ambiente["origem"]:
            return ambiente["codigo"]

# %%
ares_df["destino"] = ares_df.origem.apply(find_destino)

# %%
AMBIENTES = {}

for codigo in ares_df.origem.unique():
    docref = db.document(f"ambientes/{codigo}")
    doc = docref.get().to_dict()
    AMBIENTES[codigo] = doc

# %%
AMBIENTES["B110"]
# Out:
# {'codigo': 'B110',
#  'edificio': 'BNU03 - Bloco Acadêmico B',
#  'items': 15,
#  'nome': 'LABCTI - LABORATÓRIO DE CIÊNCIA, TECNOLOGIA E INOVAÇÃO (1º Andar)',
#  'status': 'Em uso',
#  'campus': 'Sul',
#  'lider': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265ff10>}

# %%
initial = {'a': 1, 'b': 2, 'obj': {'c': 3, 'd': 4}}

second = deepcopy(initial)

second['obj']['c'] = 5

print(initial)
# Out:
# {'a': 1, 'b': 2, 'obj': {'c': 3, 'd': 4}}

# %%
def create_part(item_original: dict, part_dict: dict): 
    """part_dict: dict with keys: codigo, descricao, medidas, peso
    """
    item = deepcopy(item_original) 
    item["key"] = f"{item_original['key']}-{part_dict['codigo']}"
    item["tipo"] = "Parte"
    item["short_descricao"] = part_dict["descricao"] 
    item["meta"]["partes"] = []
    item["meta"]["inteiro"] = True
    item["meta"]["volumado"] = False
    item["meta"]["partes"] = []
    item["meta"]["updated"] = datetime.now(tz=datetime.now().astimezone().tzinfo)
    item["detalhes"]["descricao"] = item_original["short_descricao"] + f" - {part_dict['descricao']}"
    item["detalhes"]["medidas"] = metidas_dict_to_str(part_dict["medidas"])
    item["detalhes"]["peso"] = int(part_dict["peso"])
    return item

def metidas_dict_to_str(medidas_dict: dict):
    return f"{medidas_dict['a']} x {medidas_dict['l']} x {medidas_dict['c']} (AxLxC)"

# %%
def generate_partes_dict(index: int):
    row = ARES_SIZES.iloc[index] 
    medidas_dict = {"a": int(row.A), "l": int(row.L), "c": int(row.C)}
    return {"codigo": row.Unidade[0], "descricao": "Unidade " + row.Unidade, "medidas": medidas_dict, "peso": int(row.Peso)}

# %%
def generate_generic_partes_dict(btus):
    groupby = ARES_SIZES[ARES_SIZES.BTUS == btus].groupby("Unidade")
    values = groupby.agg({"A": 'max', "L": 'max', "C": 'max', "Peso": 'max'})
    resultado = values.reset_index()
    for index, row in resultado.iterrows():
        medidas_dict = {"a": int(row.A), "l": int(row.L), "c": int(row.C)}
        yield {"codigo": row.Unidade[0], "descricao": "Unidade " + row.Unidade, "medidas": medidas_dict, "peso": int(row.Peso)}

# %%
list(generate_generic_partes_dict(9000))
# Out:
# [{'codigo': 'E',
#   'descricao': 'Unidade Externa',
#   'medidas': {'a': 55, 'l': 78, 'c': 32},
#   'peso': 29},
#  {'codigo': 'I',
#   'descricao': 'Unidade Interna',
#   'medidas': {'a': 29, 'l': 86, 'c': 20},
#   'peso': 10}]

# %%
def find_ar_data(ar_row: pd.Series):
    btus_mask = ARES_SIZES["BTUS"] == ar_row["btus"]
    marca_mask = ARES_SIZES["Marca"] == ar_row["marca"]
    modelo_mask = ARES_SIZES["Modelo"] == ar_row["real_modelo"]
    mask = btus_mask & marca_mask & modelo_mask
    return ARES_SIZES[mask]

# %%
from datetime import datetime

def create_volume(item_dict: dict , parte_dict: dict):
    lider = AMBIENTES[item_dict['origem']]['lider']
    destino_str = find_destino(item_dict['origem'])
    destino = db.document(f"ambientes-norte/{destino_str}")
    itemref = db.document(f"items/{item_dict['key']}")
    volume_model = {'medidas': parte_dict['medidas'],
        'categoria': 'Ar Condicionado',
        'peso': parte_dict['peso'],
        'items': [itemref],
        'observacao': 'Criado pelo sistema', 
        'data_criacao': datetime.now(),
        'embalagem': {'caixa': None,
        'platico_bolha': None,
        'enchimento': True},
        'responsavel': lider,
        'origem': item_dict['ambiente'],
        'destino': destino,
        'propriedades': ['Frágil', 'Proibido Empilhar'],
        'codigo': f"V{item_dict['key']}".replace("-", ""),
        'servicos': ['Montagem e Desmontagem', 'Especializados'],
        'status': ['Criado', 'Para Desmontagem'],
        'localizacao_atual':  item_dict['ambiente'],
        'deleted': False}    
    return volume_model

# %%
def process_data(data_string):
    try:
        return datetime.fromisoformat(data_string, tz=datetime.now().astimezone().tzinfo)
    except:
        return None


def process_item(item: dict): 
    copia = deepcopy(item) 
    copia["meta"]["inteiro"] = False
    copia["meta"]["volumado"] = False
    copia["meta"]["volume"] = None
    copia["meta"]["updated"] = datetime.now(tz=datetime.now().astimezone().tzinfo)
    copia["ambiente"] = db.document(f"ambientes/{copia['origem']}")
    copia["detalhes"]["incorporacao"] = process_data(item["detalhes"]["incorporacao"]) 
    copia["detalhes"]["transf_local"] = process_data(item["detalhes"]["transf_local"]) 
    codigo = item["key"]
    thisindex = ares_df[ ares_df.codigo == codigo].index
    row = ares_df.iloc[thisindex[0],:]
    partes_dict = [generate_partes_dict(x) for x in find_ar_data(row).index]
    if len(partes_dict) == 2:
        pass # tudo certo
    else:
        partes_dict = list(generate_generic_partes_dict(row.btus))
    novas_partes = [create_part(copia, x) for x in partes_dict]
    copia["meta"]["partes"] = [db.document(f"items/{x['key']}") for x in novas_partes]
    volumes = [create_volume(x, y) for (x,y) in zip(novas_partes,partes_dict)]
    return copia, novas_partes, volumes

# %%
process_item(ares_condicionados[15])
# Out:
# ({'origem': 'A101',
#   'edificio': 'BNU02 - Bloco Acadêmico A',
#   'short_descricao': 'CONDICIONADOR DE AR SPLIT INVERTER',
#   'key': 322569,
#   'tipo': 'Permanente',
#   'ambiente': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802930a0>,
#   'meta': {'volume': None,
#    'updated': datetime.datetime(2023, 12, 14, 16, 8, 8, 348890, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=75600), '-03')),
#    'inteiro': False,
#    'volumado': False,
#    'partes': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027bd90>,
#     <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802936a0>]},
#   'detalhes': {'patrimonio': 510164,
#    'medidas': '',
#    'valor': 1039.05,
#    'n_controle': nan,
#    'descricao': 'CONDICIONADOR DE AR SPLIT INVERTER - HI-WALL COM ROTAÇÃO VARIÁVEL \x96 CAPACIDADE 11.500 A 12.000 BTU/H, FRIO, COM INSTALAÇÃO INCLUSA - CONDICIONADOR DE AR SPLIT, 12.000 BTUS, MARCA ELECTROLUX, MODELO BI12F, FRIO, COR BRANCA, 220V. ACOMPANHA CONTROLE REMOTO, MANUAL, ACESSÓRIOS E UNIDADE CONDENSADORA.',
#    'peso': '',
#    'n_serie': nan,
#    'cod_barras': 322569,
#    'incorporacao': None,
#    'conservacao': 'EM USO',
#    'transf_local': None,
#    'situacao': 'Ativo'},
#   'responsavel': 'Rafael dos Reis Abreu'},
#  [{'origem': 'A101',
#    'edificio': 'BNU02 - Bloco Acadêmico A',
#    'short_descricao': 'Unidade Interna',
#    'key': '322569-I',
#    'tipo': 'Parte',
#    'ambiente': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3831b9510>,
#    'meta': {'volume': None,
#     'updated': datetime.datetime(2023, 12, 14, 16, 8, 8, 354024, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=75600), '-03')),
#     'inteiro': True,
#     'volumado': False,
#     'partes': []},
#    'detalhes': {'patrimonio': 510164,
#     'medidas': '29 x 92 x 19 (AxLxC)',
#     'valor': 1039.05,
#     'n_controle': nan,
#     'descricao': 'CONDICIONADOR DE AR SPLIT INVERTER - Unidade Interna',
#     'peso': 11,
#     'n_serie': nan,
#     'cod_barras': 322569,
#     'incorporacao': None,
#     'conservacao': 'EM USO',
#     'transf_local': None,
#     'situacao': 'Ativo'},
#    'responsavel': 'Rafael dos Reis Abreu'},
#   {'origem': 'A101',
#    'edificio': 'BNU02 - Bloco Acadêmico A',
#    'short_descricao': 'Unidade Externa',
#    'key': '322569-E',
#    'tipo': 'Parte',
#    'ambiente': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa383302c20>,
#    'meta': {'volume': None,
#     'updated': datetime.datetime(2023, 12, 14, 16, 8, 8, 354208, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=75600), '-03')),
#     'inteiro': True,
#     'volumado': False,
#     'partes': []},
#    'detalhes': {'patrimonio': 510164,
#     'medidas': '54 x 85 x 32 (AxLxC)',
#     'valor': 1039.05,
#     'n_controle': nan,
#     'descricao': 'CONDICIONADOR DE AR SPLIT INVERTER - Unidade Externa',
#     'peso': 32,
#     'n_serie': nan,
#     'cod_barras': 322569,
#     'incorporacao': None,
#     'conservacao': 'EM USO',
#     'transf_local': None,
#     'situacao': 'Ativo'},
#    'responsavel': 'Rafael dos Reis Abreu'}],
#  [{'medidas': {'a': 29, 'l': 92, 'c': 19},
#    'categoria': 'Ar Condicionado',
#    'peso': 11,
#    'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380291db0>],
#    'observacao': 'Criado pelo sistema',
#    'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 8, 354352),
#    'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#    'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265fbe0>,
#    'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3831b9510>,
#    'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802900a0>,
#    'propriedades': ['Frágil', 'Proibido Empilhar'],
#    'codigo': 'V322569I',
#    'servicos': ['Montagem e Desmontagem', 'Especializados'],
#    'status': ['Criado', 'Para Desmontagem'],
#    'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3831b9510>,
#    'deleted': False},
#   {'medidas': {'a': 54, 'l': 85, 'c': 32},
#    'categoria': 'Ar Condicionado',
#    'peso': 32,
#    'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380290940>],
#    'observacao': 'Criado pelo sistema',
#    'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 8, 354402),
#    'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#    'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265fbe0>,
#    'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa383302c20>,
#    'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380290580>,
#    'propriedades': ['Frágil', 'Proibido Empilhar'],
#    'codigo': 'V322569E',
#    'servicos': ['Montagem e Desmontagem', 'Especializados'],
#    'status': ['Criado', 'Para Desmontagem'],
#    'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa383302c20>,
#    'deleted': False}])

# %%
from google.cloud.firestore_v1.document import DocumentReference

def process_reference(reference: DocumentReference):
    return reference.path

def process_array(array: list):
    return [process_reference(item) if type(item) == DocumentReference else item for item in array]

def process_dict(input_dict):
    output_dict = {}
    for key, value in input_dict.items():
        if type(value) == DocumentReference:
            output_dict[key] = process_reference(value)
        elif isinstance(value, dict):
            output_dict[key] = process_dict(value)
        elif isinstance(value, list):
            output_dict[key] = process_array(value)
        elif isinstance(value, datetime):
            output_dict[key] = value.isoformat()
        else:
            output_dict[key] = value
    return output_dict

# %%
[x for x in ares_condicionados if x["key"] == 322563]
# Out:
# [{'origem': 'B117',
#   'edificio': 'BNU03 - Bloco Acadêmico B',
#   'short_descricao': 'CONDICIONADOR DE AR SPLIT INVERTER',
#   'key': 322563,
#   'tipo': 'Permanente',
#   'ambiente': 'ambientes/B117',
#   'meta': {'volume': 'volumes/B1170017',
#    'updated': '2023-09-14T11:40:32+00:00',
#    'inteiro': True,
#    'volumado': True,
#    'partes': []},
#   'detalhes': {'patrimonio': 510158,
#    'medidas': '',
#    'valor': 1039.05,
#    'n_controle': nan,
#    'descricao': 'CONDICIONADOR DE AR SPLIT INVERTER - HI-WALL COM ROTAÇÃO VARIÁVEL \x96 CAPACIDADE 11.500 A 12.000 BTU/H, FRIO, COM INSTALAÇÃO INCLUSA - CONDICIONADOR DE AR SPLIT, 12.000 BTUS, MARCA ELECTROLUX, MODELO BI12F, FRIO, COR BRANCA, 220V. ACOMPANHA CONTROLE REMOTO, MANUAL, ACESSÓRIOS E UNIDADE CONDENSADORA.',
#    'peso': '',
#    'n_serie': nan,
#    'cod_barras': 322563,
#    'incorporacao': '2014-05-15T00:00:00+00:00',
#    'conservacao': 'EM USO',
#    'transf_local': '2017-11-17T00:00:00+00:00',
#    'situacao': 'Ativo'},
#   'responsavel': 'Rafael dos Reis Abreu'}]

# %%
def process_all_ares():
    for ar in [x for x in ares_condicionados if type(x['key']) == int]:
        item_original, lista_partes, lista_volumes = process_item(ar) 
        yield item_original, lista_partes, lista_volumes

# %%
import json
lista = [{'original': a, 'partes': b, 'volumes': c} for (a,b,c) in process_all_ares()]
with open("arescondicionares.json", "w") as fp:
    json.dump(lista, fp, indent=2, ensure_ascii=False, default=str)

# %%
ares107 = [x for x in ares_condicionados if x["origem"] == "A107"]

# %%
_items = {}
_volumes = {}
for item_original, lista_partes, lista_volumes in process_all_ares():
    _items[item_original["key"]] = item_original
    for parte in lista_partes:
        _items[parte["key"]] = parte
    for volume in lista_volumes:
        _volumes[volume["codigo"]] = volume

# %%
def typer(dicionario):
    if isinstance(dicionario, dict):
        return {k: typer(v) for (k,v) in dicionario.items()}
    else:
        return type(dicionario)

for key, value in _items.items(): 
    #print(typer(value))
    db.document(f"items/{key}").set(value)

# %%
for key, value in _items.items(): 
    print(typer(value))
# Out:
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'key': <class 'int'>, 'short_descricao': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'incorporacao': <class 'NoneType'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'peso': <class 'str'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'key': <class 'str'>, 'short_descricao': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'incorporacao': <class 'NoneType'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'peso': <class 'int'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'key': <class 'str'>, 'short_descricao': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'incorporacao': <class 'NoneType'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'peso': <class 'int'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'int'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'int'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'int'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'int'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'int'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'int'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'int'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'int'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'int'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'key': <class 'int'>, 'short_descricao': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'volumado': <class 'bool'>, 'inteiro': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'incorporacao': <class 'NoneType'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'peso': <class 'str'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'key': <class 'str'>, 'short_descricao': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'volumado': <class 'bool'>, 'inteiro': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'incorporacao': <class 'NoneType'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'peso': <class 'int'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'key': <class 'str'>, 'short_descricao': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'volumado': <class 'bool'>, 'inteiro': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'incorporacao': <class 'NoneType'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'peso': <class 'int'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# ...
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'str'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'str'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'str'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'str'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'str'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'str'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'str'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'str'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'str'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'str'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'str'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'str'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'int'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'edificio': <class 'str'>, 'short_descricao': <class 'str'>, 'key': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'float'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'n_serie': <class 'float'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'responsavel': <class 'str'>}
# {'origem': <class 'str'>, 'key': <class 'int'>, 'edificio': <class 'str'>, 'responsavel': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'int'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'str'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'n_serie': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'short_descricao': <class 'str'>}
# {'origem': <class 'str'>, 'key': <class 'str'>, 'edificio': <class 'str'>, 'responsavel': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'int'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'n_serie': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'short_descricao': <class 'str'>}
# {'origem': <class 'str'>, 'key': <class 'str'>, 'edificio': <class 'str'>, 'responsavel': <class 'str'>, 'tipo': <class 'str'>, 'ambiente': <class 'google.cloud.firestore_v1.document.DocumentReference'>, 'meta': {'volume': <class 'NoneType'>, 'updated': <class 'datetime.datetime'>, 'inteiro': <class 'bool'>, 'volumado': <class 'bool'>, 'partes': <class 'list'>}, 'detalhes': {'patrimonio': <class 'int'>, 'medidas': <class 'str'>, 'valor': <class 'int'>, 'n_controle': <class 'float'>, 'descricao': <class 'str'>, 'peso': <class 'int'>, 'cod_barras': <class 'int'>, 'incorporacao': <class 'NoneType'>, 'conservacao': <class 'str'>, 'n_serie': <class 'str'>, 'transf_local': <class 'NoneType'>, 'situacao': <class 'str'>}, 'short_descricao': <class 'str'>}

# %%
for key, value in _volumes.items(): 
    #print(typer(value))
    db.document(f"volumes/{key}").set(value)

# %%
_volumes
# Out:
# {'V227811E': {'medidas': {'a': 55, 'l': 78, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 29,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249f30>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 436988),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265ff10>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a110>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a860>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227811E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a110>,
#   'deleted': False},
#  'V227811I': {'medidas': {'a': 29, 'l': 86, 'c': 20},
#   'categoria': 'Ar Condicionado',
#   'peso': 10,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249f00>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 437027),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265ff10>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a980>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249c60>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227811I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a980>,
#   'deleted': False},
#  'V227821E': {'medidas': {'a': 55, 'l': 78, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 29,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249480>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 442907),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f6d0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802499c0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024bac0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227821E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802499c0>,
#   'deleted': False},
#  'V227821I': {'medidas': {'a': 29, 'l': 86, 'c': 20},
#   'categoria': 'Ar Condicionado',
#   'peso': 10,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249a50>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 442924),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f6d0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024b820>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a7d0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227821I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024b820>,
#   'deleted': False},
#  'V227828E': {'medidas': {'a': 55, 'l': 78, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 29,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248be0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 447714),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265fcd0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249180>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248130>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227828E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249180>,
#   'deleted': False},
#  'V227828I': {'medidas': {'a': 29, 'l': 86, 'c': 20},
#   'categoria': 'Ar Condicionado',
#   'peso': 10,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248f40>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 447730),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265fcd0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249b40>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248700>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227828I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249b40>,
#   'deleted': False},
#  'V227831E': {'medidas': {'a': 55, 'l': 78, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 29,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248370>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 451931),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f640>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248880>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802493f0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227831E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248880>,
#   'deleted': False},
#  'V227831I': {'medidas': {'a': 29, 'l': 86, 'c': 20},
#   'categoria': 'Ar Condicionado',
#   'peso': 10,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802485b0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 451947),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f640>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249090>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249900>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227831I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249090>,
#   'deleted': False},
#  'V227839E': {'medidas': {'a': 55, 'l': 78, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 29,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024bbb0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 455375),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f520>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024bc10>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248c40>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227839E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024bc10>,
#   'deleted': False},
#  'V227839I': {'medidas': {'a': 29, 'l': 86, 'c': 20},
#   'categoria': 'Ar Condicionado',
#   'peso': 10,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024b550>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 455393),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f520>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802485e0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802484c0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227839I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802485e0>,
#   'deleted': False},
#  'V227841E': {'medidas': {'a': 55, 'l': 78, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 29,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024ab60>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 458838),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f2e0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024b310>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802483d0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227841E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024b310>,
#   'deleted': False},
#  'V227841I': {'medidas': {'a': 29, 'l': 86, 'c': 20},
#   'categoria': 'Ar Condicionado',
#   'peso': 10,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249360>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 458865),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f2e0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249d20>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248490>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227841I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249d20>,
#   'deleted': False},
#  'V227855E': {'medidas': {'a': 56, 'l': 103, 'c': 75},
#   'categoria': 'Ar Condicionado',
#   'peso': 44,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a170>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 462259),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f460>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024aaa0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024b850>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227855E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024aaa0>,
#   'deleted': False},
#  'V227855I': {'medidas': {'a': 33, 'l': 101, 'c': 38},
#   'categoria': 'Ar Condicionado',
#   'peso': 12,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a890>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 462273),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f460>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024b250>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a6e0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227855I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024b250>,
#   'deleted': False},
#  'V227868E': {'medidas': {'a': 56, 'l': 103, 'c': 75},
#   'categoria': 'Ar Condicionado',
#   'peso': 44,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249ba0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 465646),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f430>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a050>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024af50>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227868E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a050>,
#   'deleted': False},
#  'V227868I': {'medidas': {'a': 33, 'l': 101, 'c': 38},
#   'categoria': 'Ar Condicionado',
#   'peso': 12,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249f90>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 465663),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f430>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a950>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024ab90>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V227868I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a950>,
#   'deleted': False},
#  'V318753I': {'medidas': {'a': 28, 'l': 86, 'c': 18},
#   'categoria': 'Ar Condicionado',
#   'peso': 10,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024af20>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 466999),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f220>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249870>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024abf0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V318753I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249870>,
#   'deleted': False},
#  'V318753E': {'medidas': {'a': 54, 'l': 78, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 29,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248e80>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 467022),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f220>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024ba90>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024bd30>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V318753E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024ba90>,
#   'deleted': False},
#  'V322563I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024bca0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 468308),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f490>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a590>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249780>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322563I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a590>,
#   'deleted': False},
#  'V322563E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024ada0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 468324),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f490>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248160>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a560>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322563E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248160>,
#   'deleted': False},
#  'V322564I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a5c0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 469607),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f280>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802496f0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248970>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322564I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802496f0>,
#   'deleted': False},
#  'V322564E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249b70>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 469622),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f280>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249720>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802482e0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322564E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380249720>,
#   'deleted': False},
#  'V322565I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802495d0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 470947),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f550>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248af0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248730>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322565I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248af0>,
#   'deleted': False},
#  'V322565E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248040>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 470967),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f550>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248cd0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248b50>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322565E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248cd0>,
#   'deleted': False},
#  'V322566I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027b430>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 472287),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f670>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024ac20>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279ed0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322566I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024ac20>,
#   'deleted': False},
#  'V322566E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278160>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 472300),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f670>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a080>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a8c0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322566E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38024a080>,
#   'deleted': False},
#  'V322567I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279990>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 473602),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f250>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802488e0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279b40>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322567I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802488e0>,
#   'deleted': False},
#  'V322567E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a920>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 473625),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f250>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248190>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027ace0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322567E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380248190>,
#   'deleted': False},
#  'V322568I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a440>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 475120),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265fe50>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027b370>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a830>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322568I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027b370>,
#   'deleted': False},
#  'V322568E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027ba00>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 475138),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265fe50>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279060>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027b130>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322568E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279060>,
#   'deleted': False},
#  'V322569I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a0b0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 476424),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265fbe0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a020>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027b670>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322569I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a020>,
#   'deleted': False},
#  'V322569E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a680>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 476440),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265fbe0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027b550>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027b7f0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322569E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027b550>,
#   'deleted': False},
#  'V322570I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a5f0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 477746),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265c880>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278880>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279000>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322570I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278880>,
#   'deleted': False},
#  'V322570E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278910>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 477773),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265c880>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802788e0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278cd0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322570E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802788e0>,
#   'deleted': False},
#  'V322571I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278e50>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 479061),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265fdf0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278c70>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278220>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322571I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278c70>,
#   'deleted': False},
#  'V322571E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278760>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 479073),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265fdf0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278d00>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278a60>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322571E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278d00>,
#   'deleted': False},
#  'V322572I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278c10>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 480347),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265fe20>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279570>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027aef0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322572I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279570>,
#   'deleted': False},
#  'V322572E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802792a0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 480361),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265fe20>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279600>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a3e0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322572E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279600>,
#   'deleted': False},
#  'V322573I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a6b0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 481658),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380520700>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278ee0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027b280>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322573I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278ee0>,
#   'deleted': False},
#  'V322573E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a590>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 481679),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380520700>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027ba30>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279510>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322573E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027ba30>,
#   'deleted': False},
#  'V322574I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279c30>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 482969),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380520be0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279c90>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278b80>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322574I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279c90>,
#   'deleted': False},
#  'V322574E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278700>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 482984),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380520be0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027bac0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027bbe0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322574E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027bac0>,
#   'deleted': False},
#  'V322575I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802799c0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 484270),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805207c0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027bbb0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802785b0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322575I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027bbb0>,
#   'deleted': False},
#  'V322575E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027acb0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 484289),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805207c0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a260>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027bb80>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322575E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a260>,
#   'deleted': False},
#  'V322576I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278fa0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 485574),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805209d0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278430>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278550>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322576I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278430>,
#   'deleted': False},
#  'V322576E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278040>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 485591),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805209d0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278eb0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278850>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322576E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278eb0>,
#   'deleted': False},
#  'V322577I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278460>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 486895),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380520fd0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278370>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3802790f0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322577I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278370>,
#   'deleted': False},
#  'V322577E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278130>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 486912),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380520fd0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a620>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278a00>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322577E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027a620>,
#   'deleted': False},
#  'V322578I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa383302d10>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 488216),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805200d0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380523be0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa383303b80>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322578I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380523be0>,
#   'deleted': False},
#  'V322578E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279750>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 488237),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805200d0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa383302770>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278790>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322578E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa383302770>,
#   'deleted': False},
#  'V322579I': {'medidas': {'a': 29, 'l': 92, 'c': 19},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380279540>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 489525),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380520280>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f8e0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380278ca0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V322579I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f8e0>,
#   'deleted': False},
#  'V322579E': {'medidas': {'a': 54, 'l': 85, 'c': 32},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa38027ae00>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 489538),
# ...
#   'deleted': False},
#  'V359948E': {'medidas': {'a': 46, 'l': 108, 'c': 75},
#   'categoria': 'Ar Condicionado',
#   'peso': 51,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa3803062c0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 650511),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805207f0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380307e20>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380307ca0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V359948E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380307e20>,
#   'deleted': False},
#  'V359949I': {'medidas': {'a': 32, 'l': 108, 'c': 41},
#   'categoria': 'Ar Condicionado',
#   'peso': 10,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380333700>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 651790),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380521c90>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380306860>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3803336a0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V359949I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380306860>,
#   'deleted': False},
#  'V359949E': {'medidas': {'a': 46, 'l': 108, 'c': 75},
#   'categoria': 'Ar Condicionado',
#   'peso': 51,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380333d00>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 651811),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380521c90>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380306380>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380333bb0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V359949E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380306380>,
#   'deleted': False},
#  'V359950I': {'medidas': {'a': 32, 'l': 108, 'c': 41},
#   'categoria': 'Ar Condicionado',
#   'peso': 10,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380332e00>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 653067),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380522020>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380306d40>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380332e60>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V359950I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380306d40>,
#   'deleted': False},
#  'V359950E': {'medidas': {'a': 46, 'l': 108, 'c': 75},
#   'categoria': 'Ar Condicionado',
#   'peso': 51,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380333220>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 653088),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380522020>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3803067a0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380333880>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V359950E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3803067a0>,
#   'deleted': False},
#  'V359951I': {'medidas': {'a': 32, 'l': 108, 'c': 41},
#   'categoria': 'Ar Condicionado',
#   'peso': 10,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380333eb0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 654348),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805235b0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380332770>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380332a40>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V359951I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380332770>,
#   'deleted': False},
#  'V359951E': {'medidas': {'a': 46, 'l': 108, 'c': 75},
#   'categoria': 'Ar Condicionado',
#   'peso': 51,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380332da0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 654366),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805235b0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380332800>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380332d10>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V359951E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380332800>,
#   'deleted': False},
#  'V359952I': {'medidas': {'a': 32, 'l': 108, 'c': 41},
#   'categoria': 'Ar Condicionado',
#   'peso': 10,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380330e20>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 655656),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380523370>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380331ea0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380331f90>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V359952I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380331ea0>,
#   'deleted': False},
#  'V359952E': {'medidas': {'a': 46, 'l': 108, 'c': 75},
#   'categoria': 'Ar Condicionado',
#   'peso': 51,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380332560>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 655682),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380523370>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3803304c0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3803323e0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V359952E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3803304c0>,
#   'deleted': False},
#  'V359953I': {'medidas': {'a': 32, 'l': 108, 'c': 41},
#   'categoria': 'Ar Condicionado',
#   'peso': 10,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805201c0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 727118),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380523640>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f310>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380520070>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V359953I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa38265f310>,
#   'deleted': False},
#  'V359953E': {'medidas': {'a': 46, 'l': 108, 'c': 75},
#   'categoria': 'Ar Condicionado',
#   'peso': 51,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380520910>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 727190),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380523640>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa383245b70>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805208b0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V359953E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa383245b70>,
#   'deleted': False},
#  'V363979I': {'medidas': {'a': 28, 'l': 69, 'c': 20},
#   'categoria': 'Ar Condicionado',
#   'peso': 8,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380521600>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 729328),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805236d0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380523010>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805218d0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V363979I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380523010>,
#   'deleted': False},
#  'V363979E': {'medidas': {'a': 51, 'l': 67, 'c': 26},
#   'categoria': 'Ar Condicionado',
#   'peso': 22,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380332650>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 729366),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805236d0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380521750>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3803321a0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V363979E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380521750>,
#   'deleted': False},
#  'V363980I': {'medidas': {'a': 28, 'l': 69, 'c': 20},
#   'categoria': 'Ar Condicionado',
#   'peso': 8,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380331480>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 731503),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380523760>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380521210>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3803315d0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V363980I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380521210>,
#   'deleted': False},
#  'V363980E': {'medidas': {'a': 51, 'l': 67, 'c': 26},
#   'categoria': 'Ar Condicionado',
#   'peso': 22,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380331ba0>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 731559),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380523760>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380522080>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380330130>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V363980E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380522080>,
#   'deleted': False},
#  'V420030E': {'medidas': {'a': 56, 'l': 85, 'c': 40},
#   'categoria': 'Ar Condicionado',
#   'peso': 32,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380333790>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 735987),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805237f0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380333df0>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380333a00>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V420030E',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380333df0>,
#   'deleted': False},
#  'V420030I': {'medidas': {'a': 30, 'l': 92, 'c': 20},
#   'categoria': 'Ar Condicionado',
#   'peso': 11,
#   'items': [<google.cloud.firestore_v1.document.DocumentReference at 0x7fa380333d30>],
#   'observacao': 'Criado pelo sistema',
#   'data_criacao': datetime.datetime(2023, 12, 14, 16, 8, 38, 736003),
#   'embalagem': {'caixa': None, 'platico_bolha': None, 'enchimento': True},
#   'responsavel': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3805237f0>,
#   'origem': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380330310>,
#   'destino': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa3803312d0>,
#   'propriedades': ['Frágil', 'Proibido Empilhar'],
#   'codigo': 'V420030I',
#   'servicos': ['Montagem e Desmontagem', 'Especializados'],
#   'status': ['Criado', 'Para Desmontagem'],
#   'localizacao_atual': <google.cloud.firestore_v1.document.DocumentReference at 0x7fa380330310>,
#   'deleted': False}}

# %%
query = db.collection("volumes").where(filter=FieldFilter("categoria", '==', 'Ar Condicionado')).where(filter=FieldFilter("destino", '==', db.document("ambientes-norte/None")))

# %%
ERRADOS = []
for volume in query.stream():
    ERRADOS.append(volume.to_dict())

# %%
CORRECT_DESTINOS = {
    "A004": "B018",
    "A201": "A029.12",
    "A211": "A023",
    "B003": "A050",
    "B025": "A029.10",
    "B105": "A131",
    "B121": "B118",
    "C204.1": "B213",
    "C306": "B206",
    "C401": "B315"
}

CORRECT_DESTINOS = {db.document(f"ambientes/{k}"): db.document(f"ambientes-norte/{v}") for (k,v) in CORRECT_DESTINOS.items()}

# %%
for x in ERRADOS:
    #x["destino"] = CORRECT_DESTINOS[x["origem"]]
    db.document(f"volumes/{x['codigo']}").update({"destino": CORRECT_DESTINOS[x["origem"]]})

# %%
query = db.collection("volumes").where(filter=FieldFilter("categoria", '==', 'Ar Condicionado')).where(filter=FieldFilter("responsavel", '==', db.document("usuarios/flavio.jerez@ufsc.br")))

for volume in query.stream():
    volume_dict = volume.to_dict()
    print(volume_dict["codigo"])
# Out:
# 9QIBwQrzFH8tv4jqgcCH
# EtYeOVWnAOYVU22yxQDe
# IwPhkEpQvZ7sLddFBxBa
# IywY5B16BE2xwaxWDJMM
# LNoZHj8FoCnKtNgRlGe7
# OJvzObxroQymXkbkJB2F
# RFrJISyvTMSaJ9UHbW0l
# V322577E
# V322577I
# b1XiR9nalvYzn367yHwL
# b4YJfBzStmwtGTqW8CJJ
# cOumWP8VDfnJoXgR03QF
# llRFzySnqnlCimbA9uDc
# xzxir6fpIojM4yPBZWK3
