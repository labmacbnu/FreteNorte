# %%
import json 

def load_json_file(file_name):
    with open(file_name, 'r') as f:
        return json.load(f)
    
def save_json_file(file_name, data):
    with open(file_name, 'w') as f:
        json.dump(data, f, indent=2, ensure_ascii=False)

# %%
from pathlib import Path

OLD_VERSION =  Path('json0914') / 'permanentes.json'
NEW_VERSION =  Path('json0929') / 'permanentes.json'

# %%
old_data = load_json_file(OLD_VERSION)
new_data = load_json_file(NEW_VERSION)

# %%
COMPARE_DB = {}

for registry in new_data:
    chave = registry['key']
    new_meta = registry.pop('meta')
    new_val = registry
    old_val = next(filter(lambda x: x['key'] == chave, old_data), None)
    if old_val is None:
        COMPARE_DB[chave] = {'new': new_val, 'old': None}
        continue
    else:
        old_meta = old_val.pop('meta')
        COMPARE_DB[chave] = {'old': old_val, 'new': new_val}

# %%
def show_dict_diff(dict1: dict, dict2: dict, prefix: str = '', level: int = 0):
    for key in dict1:
        if key not in dict2:
            print(f'Key {key} not in dict2')
            continue
        if dict1[key] != dict2[key]:
            if type(dict1[key]) == dict:
                show_dict_diff(dict1[key], dict2[key], prefix + key + '.', level + 1)
            else:
                print(f'Key {key} has different values')
                print("  "*(level + 1) + f'dict1[{prefix}{key}]: {dict1[key]}')
                print("  "*(level + 1) + f'dict2[{prefix}{key}]: {dict2[key]}')

def return_dict_diff(dict1: dict, dict2: dict, prefix: str = '', level: int = 0):
    diff = {}
    for key in dict1:
        if key not in dict2:
            diff[key] = {'d1': dict1[key], 'd2': None}
            continue
        if dict1[key] != dict2[key]:
            if type(dict1[key]) == dict:
                diff[key] = return_dict_diff(dict1[key], dict2[key], prefix + key + '.', level + 1)
            else:
                diff[key] = {'d1': dict1[key], 'd2': dict2[key]}
    for key in dict2:
        if key not in dict1:
            diff[key] = {'d1': None, 'd2': dict2[key]}
            continue
        if dict1[key] != dict2[key]:
            if type(dict1[key]) == dict:
                diff[key] = return_dict_diff(dict1[key], dict2[key], prefix + key + '.', level + 1)
            else:
                diff[key] = {'d1': dict1[key], 'd2': dict2[key]}
    return diff

# %%
d1 = {"nome": "Luiz", "meta": {"idade": 29, 'trusth': True}, "teste": {"teste2": {"teste3": 1}}}
d2 = {"nome": "Luiz", "meta": {"idade": 30, 'trusth': True}, "teste": {"teste1": {"teste3": 4}}}
return_dict_diff(d1, d2)
# Out:
# {'meta': {'idade': {'d1': 29, 'd2': 30}},
#  'teste': {'teste2': {'d1': {'teste3': 1}, 'd2': None},
#   'teste1': {'d1': None, 'd2': {'teste3': 4}}}}

# %%
DIFF_DICT = {'modified': {}, 'new': {}}
for key, val in COMPARE_DB.items():
    if val['old'] == None:
        DIFF_DICT['new'][key] = val['new']
    elif val['old'] != val['new']: 
        show_dict_diff(val['new'], val['old'])
        DIFF_DICT['modified'][key] = return_dict_diff(val['new'], val['old'])
# Out:
# Key responsavel has different values
#   dict1[responsavel]: Tiago Davi Curi Busarello
#   dict2[responsavel]: Daniel Alejandro Ponce Saldias
# Key ambiente has different values
#   dict1[ambiente]: B114
#   dict2[ambiente]: C304
# Key edificio has different values
#   dict1[edificio]: BNU03 - Bloco Acadêmico B
#   dict2[edificio]: BNU07 - Bloco Administrativo C
# Key transf_local has different values
#     dict1[detalhes.transf_local]: 20/09/2023
#     dict2[detalhes.transf_local]: 15/08/2022
# Key origem has different values
#   dict1[origem]: B114
#   dict2[origem]: C304
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Carolina Suelen da Silva
# Key ambiente has different values
#   dict1[ambiente]: A201
#   dict2[ambiente]: B026
# Key edificio has different values
#   dict1[edificio]: BNU02 - Bloco Acadêmico A
#   dict2[edificio]: BNU03 - Bloco Acadêmico B
# Key transf_local has different values
#     dict1[detalhes.transf_local]: 15/09/2023
#     dict2[detalhes.transf_local]: None
# Key origem has different values
#   dict1[origem]: A201
#   dict2[origem]: B026
# Key responsavel has different values
#   dict1[responsavel]: Francis Felix Cordova Puma
#   dict2[responsavel]: André Vanderlinde da Silva
# Key responsavel has different values
#   dict1[responsavel]: Francis Felix Cordova Puma
#   dict2[responsavel]: André Vanderlinde da Silva
# Key responsavel has different values
#   dict1[responsavel]: Francis Felix Cordova Puma
#   dict2[responsavel]: André Vanderlinde da Silva
# Key responsavel has different values
#   dict1[responsavel]: Francis Felix Cordova Puma
#   dict2[responsavel]: André Vanderlinde da Silva
# Key responsavel has different values
#   dict1[responsavel]: Francis Felix Cordova Puma
#   dict2[responsavel]: André Vanderlinde da Silva
# Key responsavel has different values
#   dict1[responsavel]: Francis Felix Cordova Puma
#   dict2[responsavel]: André Vanderlinde da Silva
# Key responsavel has different values
#   dict1[responsavel]: Francis Felix Cordova Puma
#   dict2[responsavel]: André Vanderlinde da Silva
# Key responsavel has different values
#   dict1[responsavel]: Francis Felix Cordova Puma
#   dict2[responsavel]: André Vanderlinde da Silva
# Key responsavel has different values
#   dict1[responsavel]: Claudio Michel Poffo
#   dict2[responsavel]: Johnny de Nardi Martins
# Key responsavel has different values
#   dict1[responsavel]: Claudio Michel Poffo
#   dict2[responsavel]: Mauri Ferrandin
# Key responsavel has different values
#   dict1[responsavel]: Daniel Martins Lima
#   dict2[responsavel]: Mauri Ferrandin
# Key responsavel has different values
#   dict1[responsavel]: Daniel Martins Lima
#   dict2[responsavel]: Johnny de Nardi Martins
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Claudio Michel Poffo
#   dict2[responsavel]: Johnny de Nardi Martins
# Key responsavel has different values
#   dict1[responsavel]: Daniel Martins Lima
#   dict2[responsavel]: Mauri Ferrandin
# Key responsavel has different values
#   dict1[responsavel]: Claudio Michel Poffo
#   dict2[responsavel]: Johnny de Nardi Martins
# Key responsavel has different values
#   dict1[responsavel]: Claudio Michel Poffo
#   dict2[responsavel]: Johnny de Nardi Martins
# Key responsavel has different values
#   dict1[responsavel]: Daniel Martins Lima
#   dict2[responsavel]: Johnny de Nardi Martins
# Key responsavel has different values
#   dict1[responsavel]: Claudio Michel Poffo
#   dict2[responsavel]: Johnny de Nardi Martins
# Key responsavel has different values
#   dict1[responsavel]: Claudio Michel Poffo
#   dict2[responsavel]: Mauri Ferrandin
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Marilise Luiza Martins dos Reis Sayao
# Key ambiente has different values
#   dict1[ambiente]: C202
#   dict2[ambiente]: C204.1
# Key transf_local has different values
#     dict1[detalhes.transf_local]: 15/09/2023
#     dict2[detalhes.transf_local]: None
# Key origem has different values
#   dict1[origem]: C202
#   dict2[origem]: C204.1
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Marilise Luiza Martins dos Reis Sayao
# Key ambiente has different values
#   dict1[ambiente]: C202
#   dict2[ambiente]: C204.1
# Key transf_local has different values
#     dict1[detalhes.transf_local]: 15/09/2023
#     dict2[detalhes.transf_local]: None
# Key origem has different values
#   dict1[origem]: C202
#   dict2[origem]: C204.1
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Marilise Luiza Martins dos Reis Sayao
# Key ambiente has different values
#   dict1[ambiente]: C202
#   dict2[ambiente]: C204.1
# Key transf_local has different values
#     dict1[detalhes.transf_local]: 15/09/2023
#     dict2[detalhes.transf_local]: None
# Key origem has different values
#   dict1[origem]: C202
#   dict2[origem]: C204.1
# Key n_serie has different values
#     dict1[detalhes.n_serie]: 22328B50P0756Q4H0MQ
#     dict2[detalhes.n_serie]: None
# Key n_serie has different values
#     dict1[detalhes.n_serie]: IC1038708
#     dict2[detalhes.n_serie]: None
# Key descricao has different values
#     dict1[detalhes.descricao]: PURIFICADOR DE AGUA - PURIFICADOR DE AGUA MARCA: CONSUL; MODELO: CPC31ABONA.
#     dict2[detalhes.descricao]: PURIFICADOR DE AGUA - PURIFICADOR DE AGUA CONSUL CPC31ABONA
# Key n_serie has different values
#     dict1[detalhes.n_serie]: 5982104001003540
#     dict2[detalhes.n_serie]: None
# Key descricao has different values
#     dict1[detalhes.descricao]: TELEFONE - TELEFONE COM FIO; MARCA: ELGIN; MODELO: 42TCF3000.
#     dict2[detalhes.descricao]: TELEFONE - TELEFONE COM FIO ELGIN 42TCF3000
# Key n_serie has different values
#     dict1[detalhes.n_serie]: TK19107012359
#     dict2[detalhes.n_serie]: None
# Key descricao has different values
#     dict1[detalhes.descricao]: ROTEADOR - ROTEADOR WIRELESS MARCA: D-LINK; MODELO: AC1200MBPS, DUALBAND, 4 ANTENAS DIR-822.
#     dict2[detalhes.descricao]: ROTEADOR - ROTEADOR WIRELESS D-LINK AC1200MBPS, DUALBAND, 4 ANTENAS DIR-822
# Key n_serie has different values
#     dict1[detalhes.n_serie]: P60000000000000000961201020134
#     dict2[detalhes.n_serie]: None
# Key descricao has different values
#     dict1[detalhes.descricao]: IMPRESSORA - IMPRESSORA 3D MARCA: 3D CREALITY - MODELO: ENDER 3
#     dict2[detalhes.descricao]: IMPRESSORA - IMPRESSORA 3D CREALITY - MODELO ENDER 3
# Key n_serie has different values
#     dict1[detalhes.n_serie]: BR2172B1K4
#     dict2[detalhes.n_serie]: None
# Key descricao has different values
#     dict1[detalhes.descricao]: IMPRESSORA - MULTIFUNCIONAL MARCA: HP MODELO: DESKJET INK ADVANTAGE - 2376
#     dict2[detalhes.descricao]: IMPRESSORA - MULTIFUNCIONALHP DESKJET INK ADVANTAGE - 2376
# Key n_serie has different values
#     dict1[detalhes.n_serie]: 469PRY21120255
#     dict2[detalhes.n_serie]: None
# Key descricao has different values
#     dict1[detalhes.descricao]: PROJETOR - PROJETOR MARCA: LG; MODELO: CINEBEAM TV BPC-1080P M18; HD, 550 LUMENS, HDMI/USB 2.1, BLUETOOTH - PH510P
#     dict2[detalhes.descricao]: PROJETOR - PROJETOR LG CINEBEAM TV, HD, 550 LUMENS, HDMI/USB 2.1, BLUETOOTH - PH510P
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Marcos Roberto Machado
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Daniel Martins Lima
# Key ambiente has different values
#   dict1[ambiente]: AC00
#   dict2[ambiente]: B024
# Key edificio has different values
#   dict1[edificio]: BNU02 - Bloco Acadêmico A
#   dict2[edificio]: BNU03 - Bloco Acadêmico B
# Key transf_local has different values
#     dict1[detalhes.transf_local]: None
#     dict2[detalhes.transf_local]: 17/11/2017
# Key origem has different values
#   dict1[origem]: AC00
#   dict2[origem]: B024
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: AC00
#   dict2[ambiente]: AC01
# Key transf_local has different values
#     dict1[detalhes.transf_local]: None
#     dict2[detalhes.transf_local]: 17/11/2017
# Key origem has different values
#   dict1[origem]: AC00
#   dict2[origem]: AC01
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: AC00
#   dict2[ambiente]: EXB02
# Key edificio has different values
#   dict1[edificio]: BNU02 - Bloco Acadêmico A
#   dict2[edificio]: BNU04 - Áreas Externas da Sede Acadêmica
# Key origem has different values
#   dict1[origem]: AC00
#   dict2[origem]: EXB02
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: AC00
#   dict2[ambiente]: BC00
# Key edificio has different values
#   dict1[edificio]: BNU02 - Bloco Acadêmico A
#   dict2[edificio]: BNU03 - Bloco Acadêmico B
# Key origem has different values
#   dict1[origem]: AC00
#   dict2[origem]: BC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: AC00
#   dict2[ambiente]: BC00
# Key edificio has different values
#   dict1[edificio]: BNU02 - Bloco Acadêmico A
#   dict2[edificio]: BNU03 - Bloco Acadêmico B
# Key origem has different values
#   dict1[origem]: AC00
#   dict2[origem]: BC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: AC00
#   dict2[ambiente]: BC00
# Key edificio has different values
#   dict1[edificio]: BNU02 - Bloco Acadêmico A
#   dict2[edificio]: BNU03 - Bloco Acadêmico B
# Key origem has different values
#   dict1[origem]: AC00
#   dict2[origem]: BC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: AC00
#   dict2[ambiente]: BC00
# Key edificio has different values
#   dict1[edificio]: BNU02 - Bloco Acadêmico A
#   dict2[edificio]: BNU03 - Bloco Acadêmico B
# Key origem has different values
#   dict1[origem]: AC00
#   dict2[origem]: BC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Carolina Suelen da Silva
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: AC01
#   dict2[ambiente]: AC00
# Key transf_local has different values
#     dict1[detalhes.transf_local]: None
#     dict2[detalhes.transf_local]: 16/11/2022
# Key origem has different values
#   dict1[origem]: AC01
#   dict2[origem]: AC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: AC01
#   dict2[ambiente]: EXB02
# Key edificio has different values
#   dict1[edificio]: BNU02 - Bloco Acadêmico A
#   dict2[edificio]: BNU04 - Áreas Externas da Sede Acadêmica
# Key origem has different values
#   dict1[origem]: AC01
#   dict2[origem]: EXB02
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: AC01
#   dict2[ambiente]: BC00
# Key edificio has different values
#   dict1[edificio]: BNU02 - Bloco Acadêmico A
#   dict2[edificio]: BNU03 - Bloco Acadêmico B
# Key origem has different values
#   dict1[origem]: AC01
#   dict2[origem]: BC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: AC01
#   dict2[ambiente]: BC00
# Key edificio has different values
#   dict1[edificio]: BNU02 - Bloco Acadêmico A
#   dict2[edificio]: BNU03 - Bloco Acadêmico B
# Key origem has different values
#   dict1[origem]: AC01
#   dict2[origem]: BC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: A307.2
#   dict2[ambiente]: A304
# Key transf_local has different values
#     dict1[detalhes.transf_local]: None
#     dict2[detalhes.transf_local]: 15/08/2019
# Key origem has different values
#   dict1[origem]: A307.2
#   dict2[origem]: A304
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Patricia Bulegon Brondani
# Key ambiente has different values
#   dict1[ambiente]: A307.2
#   dict2[ambiente]: A305
# Key transf_local has different values
#     dict1[detalhes.transf_local]: None
#     dict2[detalhes.transf_local]: 16/11/2022
# Key origem has different values
#   dict1[origem]: A307.2
#   dict2[origem]: A305
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Marilise Luiza Martins dos Reis Sayao
# Key ambiente has different values
#   dict1[ambiente]: B008
#   dict2[ambiente]: C204.1
# Key edificio has different values
#   dict1[edificio]: BNU03 - Bloco Acadêmico B
#   dict2[edificio]: BNU07 - Bloco Administrativo C
# Key n_serie has different values
#     dict1[detalhes.n_serie]: AQW43243172
#     dict2[detalhes.n_serie]: None
# Key descricao has different values
#     dict1[detalhes.descricao]: APARELHO DE AR CONDICIONADO - AR CONDICIONADO SPLIT MARCA: ELGIN; MODELO: ECO POWER 12000 BTUS FRIO ECST-12 FR4-02; 12000 BTUS FRIO 220V.
#     dict2[detalhes.descricao]: APARELHO DE AR CONDICIONADO - AR CONDICIONADO SPLIT ELGIN ECO POWER 12000 BTUS FRIO 220V
# Key transf_local has different values
#     dict1[detalhes.transf_local]: 15/09/2023
#     dict2[detalhes.transf_local]: None
# Key origem has different values
#   dict1[origem]: B008
#   dict2[origem]: C204.1
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Adao Boava
#   dict2[responsavel]: Daniel Martins Lima
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Daniel Martins Lima
# Key ambiente has different values
#   dict1[ambiente]: BC00
#   dict2[ambiente]: B016
# Key transf_local has different values
#     dict1[detalhes.transf_local]: None
#     dict2[detalhes.transf_local]: 17/11/2017
# Key origem has different values
#   dict1[origem]: BC00
#   dict2[origem]: B016
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key ambiente has different values
#   dict1[ambiente]: BC00
#   dict2[ambiente]: AC00
# Key edificio has different values
#   dict1[edificio]: BNU03 - Bloco Acadêmico B
#   dict2[edificio]: BNU02 - Bloco Acadêmico A
# Key transf_local has different values
#     dict1[detalhes.transf_local]: None
#     dict2[detalhes.transf_local]: 17/11/2017
# Key origem has different values
#   dict1[origem]: BC00
#   dict2[origem]: AC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key ambiente has different values
#   dict1[ambiente]: BC00
#   dict2[ambiente]: AC00
# Key edificio has different values
#   dict1[edificio]: BNU03 - Bloco Acadêmico B
#   dict2[edificio]: BNU02 - Bloco Acadêmico A
# Key transf_local has different values
#     dict1[detalhes.transf_local]: None
#     dict2[detalhes.transf_local]: 17/11/2017
# Key origem has different values
#   dict1[origem]: BC00
#   dict2[origem]: AC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key ambiente has different values
#   dict1[ambiente]: BC00
#   dict2[ambiente]: AC00
# Key edificio has different values
#   dict1[edificio]: BNU03 - Bloco Acadêmico B
#   dict2[edificio]: BNU02 - Bloco Acadêmico A
# Key transf_local has different values
#     dict1[detalhes.transf_local]: None
#     dict2[detalhes.transf_local]: 17/11/2017
# Key origem has different values
#   dict1[origem]: BC00
#   dict2[origem]: AC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key ambiente has different values
#   dict1[ambiente]: BC00
#   dict2[ambiente]: AC00
# Key edificio has different values
#   dict1[edificio]: BNU03 - Bloco Acadêmico B
#   dict2[edificio]: BNU02 - Bloco Acadêmico A
# Key transf_local has different values
#     dict1[detalhes.transf_local]: None
#     dict2[detalhes.transf_local]: 17/11/2017
# Key origem has different values
#   dict1[origem]: BC00
#   dict2[origem]: AC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: BC00
#   dict2[ambiente]: BC01
# Key origem has different values
#   dict1[origem]: BC00
#   dict2[origem]: BC01
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Eduardo Zapp
#   dict2[responsavel]: Jose Wilmo da Cruz Junior
# Key ambiente has different values
#   dict1[ambiente]: BC00
#   dict2[ambiente]: B026
# Key transf_local has different values
#     dict1[detalhes.transf_local]: 22/09/2023
#     dict2[detalhes.transf_local]: 16/11/2022
# Key origem has different values
#   dict1[origem]: BC00
#   dict2[origem]: B026
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Carolina Suelen da Silva
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Jorge Cássio Costa Nóbriga
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: BC01
#   dict2[ambiente]: BC00
# Key transf_local has different values
#     dict1[detalhes.transf_local]: None
#     dict2[detalhes.transf_local]: 16/11/2022
# Key origem has different values
#   dict1[origem]: BC01
#   dict2[origem]: BC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: BC01
#   dict2[ambiente]: BC00
# Key transf_local has different values
#     dict1[detalhes.transf_local]: 17/11/2017
#     dict2[detalhes.transf_local]: 15/11/2022
# Key origem has different values
#   dict1[origem]: BC01
#   dict2[origem]: BC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: BC01
#   dict2[ambiente]: BC00
# Key transf_local has different values
#     dict1[detalhes.transf_local]: 17/11/2017
#     dict2[detalhes.transf_local]: 15/11/2022
# Key origem has different values
#   dict1[origem]: BC01
#   dict2[origem]: BC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: BC01
#   dict2[ambiente]: BC00
# Key transf_local has different values
#     dict1[detalhes.transf_local]: None
#     dict2[detalhes.transf_local]: 16/11/2022
# Key origem has different values
#   dict1[origem]: BC01
#   dict2[origem]: BC00
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key ambiente has different values
#   dict1[ambiente]: BC01
#   dict2[ambiente]: EXB02
# Key edificio has different values
#   dict1[edificio]: BNU03 - Bloco Acadêmico B
#   dict2[edificio]: BNU04 - Áreas Externas da Sede Acadêmica
# Key transf_local has different values
#     dict1[detalhes.transf_local]: None
#     dict2[detalhes.transf_local]: 29/11/2019
# Key origem has different values
#   dict1[origem]: BC01
#   dict2[origem]: EXB02
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Ana Julia Dal Forno
# Key responsavel has different values
#   dict1[responsavel]: Graziela Piccoli Richetti
#   dict2[responsavel]: Carolina Suelen da Silva
# Key responsavel has different values
#   dict1[responsavel]: Rafael dos Reis Abreu
#   dict2[responsavel]: Adriano Peres

# %%
def flatten_dict(dicionary: dict) -> dict:
    flat_dict = {}
    for key, val in dicionary.items():
        if type(val) == dict:
            for sub_key, sub_val in flatten_dict(val).items():
                flat_dict[key + '.' + sub_key] = sub_val
        else:
            flat_dict[key] = val
    return flat_dict

# %%
save_json_file('diff.json', DIFF_DICT)

# %%
import pandas as pd

# %%
modificados = pd.DataFrame(DIFF_DICT['modified']).transpose()
novos = pd.DataFrame(DIFF_DICT['new']).transpose()

# %%
novos.shape, modificados.shape
# Out:
# ((41, 8), (257, 5))
